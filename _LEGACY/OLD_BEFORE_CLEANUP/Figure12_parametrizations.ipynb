# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2

from jupyterthemes import jtplot
jtplot.style()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append('../EXP/')
import ClevelandMcGill as C
reload(C)
# Out:
# <module 'ClevelandMcGill' from '../EXP/ClevelandMcGill/__init__.pyc'>

# %%
fig = C.Figure12()
fig.create(verbose=True)
fig.framed = False
fig.show()
fig.framed = True
fig.show()
# Out:
# # Parameters 25
# Label 1
# Label 1

# %%
fig = C.Figure12(variable_y=True)
fig.create(verbose=True)
fig.framed = False
fig.show()
fig.framed = True
fig.show()
# Out:
# # Parameters 15625
# Label 0
# Label 0

# %%
fig = C.Figure12(variable_y=True, variable_width=True)
fig.create(verbose=True)
fig.framed = False
fig.show()
fig.framed = True
fig.show()
# Out:
# # Parameters 1562500
# Label 0
# Label 0

# %%
fig = C.Figure12(variable_y=True, variable_width=True, variable_x=True)
fig.create(verbose=True)
fig.framed = False
fig.show()
fig.framed = True
fig.show()
# Out:
# # Parameters 156250000
# Label 0
# Label 0

# %%
sparse = fig.to_sparse()
print sparse
# Out:
# ([15, 11, 17, 62, 62, 10, 18, 61], 0)

# %%
fig2 = C.Figure12.from_sparse(sparse[0], variable_y=True, variable_width=True, variable_x=True)
fig2.framed = False
fig2.show()
fig2.framed = True
fig2.show()
# Out:
# Label 0
# Label 0

# %%
np.array_equal(fig2.to_image(), fig.to_image())
# Out:
# True
