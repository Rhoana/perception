# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2

from jupyterthemes import jtplot
jtplot.style()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append('../EXP/')
import ClevelandMcGill as C
reload(C)
# Out:
# <module 'ClevelandMcGill' from '../EXP/ClevelandMcGill/__init__.pyc'>

# %%
fig = C.Figure1_Position_Common_Scale()
fig.create(verbose=True)
fig.show()
# Out:
# Label 62

# %%
fig = C.Figure1_Position_Common_Scale(variable_x=True)
fig.create(verbose=True)
fig.show()
# Out:
# Label 51

# %%
fig = C.Figure1_Position_Common_Scale(variable_x=True, variable_spot_size=True)
fig.create(verbose=True)
fig.show()
# Out:
# Label 54

# %%
sparse = fig.to_sparse()
print sparse
# Out:
# ([21, 49, [0, 0], 3], 49)

# %%
fig2 = C.Figure1_Position_Common_Scale.from_sparse(sparse[0], variable_x=True, variable_spot_size=True)
fig2.show()
# Out:
# Label 49

# %%
np.array_equal(fig2.to_image(), fig.to_image())
# Out:
# True

# %%
fig2.show_many(10)
# Out:
# Label 25
# Label 60
# Label 74
# Label 24
# Label 66
# Label 47
# Label 30
# Label 44
# Label 59
# Label 54
# ([[32, 25, [0, 0], 3],
#   [30, 60, [0, 0], 3],
#   [73, 74, [0, 0], 11],
#   [45, 24, [0, 0], 1],
#   [25, 66, [0, 0], 1],
#   [49, 47, [0, 0], 11],
#   [53, 30, [0, 0], 9],
#   [69, 44, [0, 0], 7],
#   [62, 59, [0, 0], 1],
#   [59, 54, [0, 0], 1]],
#  [25, 60, 74, 24, 66, 47, 30, 44, 59, 54])
