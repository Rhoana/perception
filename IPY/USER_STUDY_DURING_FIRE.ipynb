# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2

from jupyterthemes import jtplot
jtplot.style()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os, sys, time
import cPickle as pickle
sys.path.append('../EXP/')
import ClevelandMcGill as C
reload(C)
# Out:
# <module 'ClevelandMcGill' from '../EXP/ClevelandMcGill/__init__.pyc'>

# %%
import cPickle as pickle
import mahotas as mh

# %%
labels = {}

for which in ['position_common_scale', 'position_non_aligned_scale', 'area', 'curvature', \
              'length', 'shading', 'volume', 'direction', 'angle']:

    labels[which] = [0] * 13
    
    for i in range(13):

        sparse, image, label, parameters = eval('C.Figure1.'+which)([True]*5)
#         print 'Label', label, 'Parameters', parameters
        image = image.astype(np.float32)
        image += np.random.uniform(0, 0.05,(100,100))

        image_ = image*255
        image_[image_ > 255] = 255
        image_ -= 255
        image_ *= -1
        image_ = image_.astype(np.uint8)

        outdir = '/home/d/CP_USERSTUDY/Figure1/' + which + '/'
        
        if not os.path.exists(outdir):
            os.makedirs(outdir)
                              
        mh.imsave(outdir+str(i)+'.png', image_)
        
        labels[which][i] = label
        
    with open(outdir+'labels.p', 'w') as f:
        pickle.dump(labels[which], f)

# %%
outdir = '/home/d/CP_USERSTUDY/Figure1/direction/'

# %%
with open(outdir+'labels.p', 'r') as f:
  aaa = pickle.load(f)

# %%
aaa
# Out:
# [155, 52, 288, 276, 50, 192, 41, 26, 248, 44, 169, 153, 302]

# %%
aaa[8]
# Out:
# 1963.4954084936207

# %%
image.shape
# Out:
# (100, 100)

# %%
aaa
# Out:
# [100, 31, 79, 79, 29, 21, 48, 32, 81, 49, 36, 38, 41]

# %%
sparse, image, label, parameters = eval('C.Figure1.direction')([True]*5, preset=360)

# %%
imshow(image)

# %%
sparse, image, label, parameters = eval('C.Figure1.direction')([True]*5, preset=90)

# %%
imshow(image)

# %%
sparse, image, label, parameters = eval('C.Figure1.direction')([True]*5, preset=240)

# %%
imshow(image)

# %%
which = 'direction'
presets = [360, 90, 240]

for p in presets:
  sparse, image, label, parameters = eval('C.Figure1.'+which)([True]*5, preset=p)
  image = image.astype(np.float32)
  image += np.random.uniform(0, 0.05,(100,100))

  imshow(image)

  image_ = image*255
  image_[image_ > 255] = 255
  image_ -= 255
  image_ *= -1
  image_ = image_.astype(np.uint8)

  outdir = '/home/d/CP_USERSTUDY/Figure1/' + which + '/'

  if not os.path.exists(outdir):
      os.makedirs(outdir)

  mh.imsave(outdir+'preset_' + str(p)+'.png', image_)

# %%
which = 'position_common_scale'
presets = [0, 30, 60]

for p in presets:
  sparse, image, label, parameters = eval('C.Figure1.'+which)([True]*5, preset=p)
  image = image.astype(np.float32)
  image += np.random.uniform(0, 0.05,(100,100))

  imshow(image)

  image_ = image*255
  image_[image_ > 255] = 255
  image_ -= 255
  image_ *= -1
  image_ = image_.astype(np.uint8)

  outdir = '/home/d/CP_USERSTUDY/Figure1/' + which + '/'

  if not os.path.exists(outdir):
      os.makedirs(outdir)

  mh.imsave(outdir+'preset_' + str(label)+'.png', image_)

# %%
which = 'position_non_aligned_scale'
presets = [-9, 0, 10]

for p in presets:
  sparse, image, label, parameters = eval('C.Figure1.'+which)([True]*5, preset=p)
  image = image.astype(np.float32)
  image += np.random.uniform(0, 0.05,(100,100))

  imshow(image)

  image_ = image*255
  image_[image_ > 255] = 255
  image_ -= 255
  image_ *= -1
  image_ = image_.astype(np.uint8)

  outdir = '/home/d/CP_USERSTUDY/Figure1/' + which + '/'

  if not os.path.exists(outdir):
      os.makedirs(outdir)

  mh.imsave(outdir+'preset_' + str(label)+'.png', image_)

# %%
label
# Out:
# 55

# %%
which = 'shading'
presets = [100,50,10]

for p in presets:
  sparse, image, label, parameters = eval('C.Figure1.'+which)([True]*5, preset=p)
  image = image.astype(np.float32)
  image += np.random.uniform(0, 0.05,(100,100))

  imshow(image)

  image_ = image*255
  image_[image_ > 255] = 255
  image_ -= 255
  image_ *= -1
  image_ = image_.astype(np.uint8)

  outdir = '/home/d/CP_USERSTUDY/Figure1/' + which + '/'

  if not os.path.exists(outdir):
      os.makedirs(outdir)

  mh.imsave(outdir+'preset_' + str(label)+'.png', image_)

# %%
which = 'volume'
presets = [1,10,20]

for p in presets:
  sparse, image, label, parameters = eval('C.Figure1.'+which)([True]*5, preset=p)
  image = image.astype(np.float32)
  image += np.random.uniform(0, 0.05,(100,100))

  imshow(image)

  image_ = image*255
  image_[image_ > 255] = 255
  image_ -= 255
  image_ *= -1
  image_ = image_.astype(np.uint8)

  outdir = '/home/d/CP_USERSTUDY/Figure1/' + which + '/'

  if not os.path.exists(outdir):
      os.makedirs(outdir)

  mh.imsave(outdir+'preset_' + str(label)+'.png', image_)

# %%
which = 'curvature'
presets = [0,0.05,0.2]

for p in presets:
  sparse, image, label, parameters = eval('C.Figure1.'+which)([True]*5)
  image = image.astype(np.float32)
  image += np.random.uniform(0, 0.05,(100,100))

  imshow(image)

  image_ = image*255
  image_[image_ > 255] = 255
  image_ -= 255
  image_ *= -1
  image_ = image_.astype(np.uint8)

  outdir = '/home/d/CP_USERSTUDY/Figure1/' + which + '/'

  if not os.path.exists(outdir):
      os.makedirs(outdir)

  mh.imsave(outdir+'preset_' + str(label)+'.png', image_)

# %%
which = 'position_common_scale'
presets = [0,0.05,0.2]

for p in presets:
  sparse, image, label, parameters = eval('C.Figure1.'+which)([True]*5)
  image = image.astype(np.float32)
  image += np.random.uniform(0, 0.05,(100,100))

  imshow(image)

  image_ = image*255
  image_[image_ > 255] = 255
  image_ -= 255
  image_ *= -1
  image_ = image_.astype(np.uint8)

  outdir = '/home/d/CP_USERSTUDY/Figure1/' + which + '/'

  if not os.path.exists(outdir):
      os.makedirs(outdir)

  mh.imsave(outdir+'preset_' + str(label)+'.png', image_)

# %%
which = 'position_non_aligned_scale'
presets = [0,0.05,0.2]

for p in presets:
  sparse, image, label, parameters = eval('C.Figure1.'+which)([True]*5)
  image = image.astype(np.float32)
  image += np.random.uniform(0, 0.05,(100,100))

  imshow(image)

  image_ = image*255
  image_[image_ > 255] = 255
  image_ -= 255
  image_ *= -1
  image_ = image_.astype(np.uint8)

  outdir = '/home/d/CP_USERSTUDY/Figure1/' + which + '/'

  if not os.path.exists(outdir):
      os.makedirs(outdir)

  mh.imsave(outdir+'preset_' + str(label)+'.png', image_)

# %% [markdown]
# # Figure 12

# %%
labels = []

for i in range(13):

  datapoint, label, parameters = C.Figure12.generate_datapoint()

#   if label[0] > label[1]:
#     labels.append('LEFT')
#   elif label[0] < label[1]:
#     labels.append('RIGHT')
#   else:
#     print 'NOOOOO'

  labels.append(label)

  # BARS
  image = C.Figure12.data_to_bars(datapoint)    
    
  image = image.astype(np.float32)
  image += np.random.uniform(0, 0.05,(100,100))

  image_ = image*255
  image_[image_ > 255] = 255
  image_ -= 255
  image_ *= -1
  image_ = image_.astype(np.uint8)

  outdir = '/home/d/CP_USERSTUDY/Figure12/bars/'

  if not os.path.exists(outdir):
      os.makedirs(outdir)
                              
  mh.imsave(outdir+str(i)+'.png', image_)
        
  # FRAMED
  image = C.Figure12.data_to_framed_rectangles(datapoint)

  image = image.astype(np.float32)
  image += np.random.uniform(0, 0.05,(100,100))

  image_ = image*255
  image_[image_ > 255] = 255
  image_ -= 255
  image_ *= -1
  image_ = image_.astype(np.uint8)

  outdir = '/home/d/CP_USERSTUDY/Figure12/framed/'

  if not os.path.exists(outdir):
      os.makedirs(outdir)
                              
  mh.imsave(outdir+str(i)+'.png', image_)      
      
with open('/home/d/CP_USERSTUDY/Figure12/labels.p', 'w') as f:
    pickle.dump(labels, f)

# %%
labels
# Out:
# [[50, 58],
#  [57, 56],
#  [50, 51],
#  [57, 49],
#  [52, 60],
#  [60, 50],
#  [57, 59],
#  [53, 57],
#  [60, 58],
#  [55, 49],
#  [60, 50],
#  [51, 57],
#  [58, 59]]

# %%
imshow(framed)

# %%
imshow(framed)

# %% [markdown]
# # Weber

# %%
bases = [10,100,1000]

for b in bases:

  labels = []
  
  for i in range(13):

    image, label = eval('C.Weber.base'+str(b))()

    labels.append(label)

    image = image.astype(np.float32)
    image += np.random.uniform(0, 0.05,(100,100))

    image_ = image*255
    image_[image_ > 255] = 255
    image_ -= 255
    image_ *= -1
    image_ = image_.astype(np.uint8)

    outdir = '/home/d/CP_USERSTUDY/Weber/' + str(b) + '/'

    if not os.path.exists(outdir):
        os.makedirs(outdir)

    mh.imsave(outdir+str(i)+'.png', image_)
           
      
  with open(outdir+'labels.p', 'w') as f:
    pickle.dump(labels, f)

# %%
labels
# Out:
# [3, 2, 4, 1, 1, 7, 10, 10, 9, 1, 10, 2, 8]

# %%
with open('/home/d/CP_USERSTUDY/Weber/10/labels.p', 'r') as f:
  aaa = pickle.load(f)

# %%
aaa
# Out:
# [9, 9, 4, 6, 7, 10, 2, 7, 3, 4, 9, 6, 6]
