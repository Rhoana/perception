# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sklearn.metrics

# %%
y_test =
# Out:
#   File "<ipython-input-4-2875e8429e82>", line 1
#     y_test =
#              ^
# SyntaxError: invalid syntax

# %%
real_v = []
for i in range(20000):
  real_v.append(np.random.randint(1,11) / 10.)
  
pred_v = [.5]*20000

np.log2(sklearn.metrics.mean_absolute_error(pred_v*100, real_v *100)+.125)

# %%
# Out:
# -1.4120014186093357

# %%
real_v[0:10]
# Out:
# [0.2, 1.0, 0.7, 0.2, 0.6, 0.3, 0.8, 0.3, 0.1, 0.1]

# %%
pred_v
# Out:
# [0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
# ...
